# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %%
data = pd.read_csv("scatter_plot_ii.csv")
data
# Out:
#      Budget  Sales
# 0     337.1   22.1
# 1     128.9   10.4
# 2     132.4    9.3
# 3     251.3   18.5
# 4     250.0   12.9
# ..      ...    ...
# 195    55.7    7.6
# 196   107.2    9.7
# 197   192.7   12.8
# 198   391.8   25.5
# 199   249.4   13.4
#
# [200 rows x 2 columns]

# %%
#plt.figure(figsize=(10,6))
sns.set_theme(rc={'figure.figsize':(9,6)})
sns.regplot(data=data,x="Budget",y="Sales",
            scatter_kws={'color':'blue'},
            line_kws={'color':'red'})
plt.xlabel("Ad expenditure in 000's $")
plt.ylabel("Sales in 000's $")
plt.show()

# %%
sns.lmplot(data=data,x="Budget",y="Sales",height=10,
            scatter_kws={'color':'blue'},
            line_kws={'color':'red'})   
plt.show()
# Out:
# c:\Users\dmont\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
