# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Real_estate(cleaned).csv",delimiter=";")
df
# Out:
#           id    building  date_sale       type property_number     area  \
# 0    ID_1030  building_1  11.1.2005  Apartment     property_30   743.09
# 1    ID_1029  building_1  10.1.2005  Apartment     property_29   756.21
# 2    ID_2002  building_2   7.1.2007  Apartment      property_2   587.28
# 3    ID_2031  building_2  12.1.2007  Apartment     property_31  1604.75
# 4    ID_1049  building_1  11.1.2004  Apartment     property_49  1375.45
# ..       ...         ...        ...        ...             ...      ...
# 195  ID_1042  building_1   7.1.2005  Apartment     property_42   625.80
# 196  ID_1002  building_1        NaN  Apartment      property_2  1238.58
# 197  ID_1003  building_1        NaN     Office      property_3   713.71
# 198  ID_1008  building_1        NaN  Apartment      property_8   763.21
# 199  ID_1019  building_1        NaN  Apartment     property_19   798.50
#
#      status customerid      entity        name   surname  birth_date gender  \
# ...

# %%
df["western"] = df["state"].apply(lambda x: "western" if x in ['Arizona', 'California', 'Colorado', 'Nevada', 'Oregon', 'Utah', 'Wyoming'] else "not west")
df.head()
# Out:
#         id    building  date_sale       type property_number     area  status  \
# 0  ID_1030  building_1  11.1.2005  Apartment     property_30   743.09   Sold
# 1  ID_1029  building_1  10.1.2005  Apartment     property_29   756.21   Sold
# 2  ID_2002  building_2   7.1.2007  Apartment      property_2   587.28   Sold
# 3  ID_2031  building_2  12.1.2007  Apartment     property_31  1604.75   Sold
# 4  ID_1049  building_1  11.1.2004  Apartment     property_49  1375.45   Sold
#
#   customerid      entity        name  ...  birth_date gender country  \
# 0      C0028  Individual     Madalyn  ...   6/21/1986      F     USA
# 1      C0027  Individual        Lara  ...   2/24/1983      F     USA
# 2      C0112  Individual     Donavan  ...  12/27/1985      M     USA
# 3      C0160  Individual      Darien  ...  12/27/1985      M     USA
# 4      C0014  Individual  Alessandra  ...   5/15/1979      F     USA
#
#         state     purpose deal_satisfaction  mortgage   source   price($)  \
# ...

# %%
df.groupby("western").count()
# Out:
#            id  building  date_sale  type  property_number  area  status  \
# western
# not west   24        24         19    24               24    24      19
# western   176       176        176   176              176   176     176
#
#           customerid  entity  name  surname  birth_date  gender  country  \
# western
# not west          19      19    19       19          19      19       19
# western          176     176   176      176         159     159      176
#
#           state  purpose  deal_satisfaction  mortgage  source  price($)
# western
# not west      5       19                 19        19      19        24
# western     176      176                176       176     176       176
