# %%
import pandas as pd
import pytz
import datetime
from datetime import date
from datetime import datetime
from matplotlib import pyplot as plt
data = pd.read_csv('Lending-company-mod-exam.csv', index_col = 'LoanID')
lending_company = data.copy()
lending_company
# Out:
#           Product CustomerGender     Location    Region  TotalPrice  \
# LoanID
# 1       Product B           Male   Location 3  Region 2     17600.0
# 2       Product B         Female   Location 6  Region 6         NaN
# 3       Product C           Male   Location 8  Region 3     16600.0
# 4       Product B           Male  Location 26  Region 2     17600.0
# 5       Product D         Female  Location 34  Region 3     21250.0
# ...           ...            ...          ...       ...         ...
# 1039    Product B           Male  Location 73  Region 6     17300.0
# 1040    Product A           Male  Location 82  Region 1         NaN
# 1041    Product A   NotSpecified  Location 11  Region 4     17300.0
# 1042    Product B         Female  Location 26  Region 6     16300.0
# 1043    Product A   NotSpecified  Location 94  Region 6     17300.0
#
#          StartDate TimeOfLoan  Deposit        LoanStatus
# LoanID
# 1       04/07/2018   23:20:56     2200            Active
# ...

# %%
lending_company["datetime"] = pd.to_datetime(lending_company["StartDate"],format='%d/%m/%Y')
lending_company.head()
# Out:
#           Product CustomerGender     Location    Region  TotalPrice  \
# LoanID
# 1       Product B           Male   Location 3  Region 2     17600.0
# 2       Product B         Female   Location 6  Region 6         NaN
# 3       Product C           Male   Location 8  Region 3     16600.0
# 4       Product B           Male  Location 26  Region 2     17600.0
# 5       Product D         Female  Location 34  Region 3     21250.0
#
#          StartDate TimeOfLoan  Deposit LoanStatus   datetime
# LoanID
# 1       04/07/2018   23:20:56     2200     Active 2018-07-04
# 2       02/01/2019   17:27:08     2200     Active 2019-01-02
# 3       08/12/2016   09:04:43     1000        NaN 2016-12-08
# 4       09/10/2016   04:25:06     2200     Active 2016-10-09
# 5       28/10/2017   11:15:47     2200     Active 2017-10-28

# %%
lending_company.iloc[3,9]-lending_company.iloc[0,9]
# Out:
# Timedelta('-633 days +00:00:00')

# %%
l3 = lending_company['StartDate'].iloc[2]+" "+lending_company['TimeOfLoan'].iloc[2]
l3
# Out:
# '08/12/2016 09:04:43'

# %%
lending_company['MOL'] = lending_company['StartDate']+" "+lending_company['TimeOfLoan']
lending_company
# Out:
#           Product CustomerGender     Location    Region  TotalPrice  \
# LoanID
# 1       Product B           Male   Location 3  Region 2     17600.0
# 2       Product B         Female   Location 6  Region 6         NaN
# 3       Product C           Male   Location 8  Region 3     16600.0
# 4       Product B           Male  Location 26  Region 2     17600.0
# 5       Product D         Female  Location 34  Region 3     21250.0
# ...           ...            ...          ...       ...         ...
# 1039    Product B           Male  Location 73  Region 6     17300.0
# 1040    Product A           Male  Location 82  Region 1         NaN
# 1041    Product A   NotSpecified  Location 11  Region 4     17300.0
# 1042    Product B         Female  Location 26  Region 6     16300.0
# 1043    Product A   NotSpecified  Location 94  Region 6     17300.0
#
#          StartDate TimeOfLoan  Deposit        LoanStatus   datetime  \
# LoanID
# ...

# %%
lending_company['MOL'] = pd.to_datetime(lending_company['MOL'],format='%d/%m/%Y %H:%M:%S')
lending_company
# Out:
#           Product CustomerGender     Location    Region  TotalPrice  \
# LoanID
# 1       Product B           Male   Location 3  Region 2     17600.0
# 2       Product B         Female   Location 6  Region 6         NaN
# 3       Product C           Male   Location 8  Region 3     16600.0
# 4       Product B           Male  Location 26  Region 2     17600.0
# 5       Product D         Female  Location 34  Region 3     21250.0
# ...           ...            ...          ...       ...         ...
# 1039    Product B           Male  Location 73  Region 6     17300.0
# 1040    Product A           Male  Location 82  Region 1         NaN
# 1041    Product A   NotSpecified  Location 11  Region 4     17300.0
# 1042    Product B         Female  Location 26  Region 6     16300.0
# 1043    Product A   NotSpecified  Location 94  Region 6     17300.0
#
#          StartDate TimeOfLoan  Deposit        LoanStatus   datetime  \
# LoanID
# ...

# %%
lending_company['MOL'].iloc[0].tz_localize('UTC')
# Out:
# Timestamp('2018-07-04 23:20:56+0000', tz='UTC')
